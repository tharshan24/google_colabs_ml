# %% [markdown]
# <a href="https://colab.research.google.com/github/tharshan24/google_colabs_ml/blob/main/SCS_3201_Random_Forest_Assignment_18001262.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd 

# import data
df = pd.read_csv('/content/mushrooms.csv')

df.head()
# Out:
#   class cap-shape cap-surface  ... spore-print-color population habitat
# 0     p         x           s  ...                 k          s       u
# 1     e         x           s  ...                 n          n       g
# 2     e         b           s  ...                 n          n       m
# 3     p         x           y  ...                 k          s       u
# 4     e         x           s  ...                 n          a       g
#
# [5 rows x 23 columns]
